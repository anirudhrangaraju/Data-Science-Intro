# %%
import pandas as pd

# %%
#To import the Data Set
data = pd.read_csv("C:\\Users\\A\\Desktop\\train_python.csv",delimiter=",")

# %%
#hELP fILE
pd.read_csv?

# %%
data.tail(5)
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 609  LP002978  Female      No          0  Graduate            No
# 610  LP002979    Male     Yes         3+  Graduate            No
# 611  LP002983    Male     Yes          1  Graduate            No
# 612  LP002984    Male     Yes          2  Graduate            No
# 613  LP002990  Female      No          0  Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 609             1.0         Rural           Y
# 610             1.0         Rural           Y
# ...

# %%
data.shape
# Out:
# (614, 13)

# %%
#To Check the Type of Data
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
#To check the head and tail of the data set
data.head(10)
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
# 5  LP001011   Male     Yes          2      Graduate           Yes
# 6  LP001013   Male     Yes          0  Not Graduate            No
# 7  LP001014   Male     Yes         3+      Graduate            No
# 8  LP001018   Male     Yes          2      Graduate            No
# 9  LP001020   Male     Yes          1      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# ...

# %%
data.tail(10)
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 604  LP002959  Female     Yes          1      Graduate            No
# 605  LP002960    Male     Yes          0  Not Graduate            No
# 606  LP002961    Male     Yes          1      Graduate            No
# 607  LP002964    Male     Yes          2  Not Graduate            No
# 608  LP002974    Male     Yes          0      Graduate            No
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 604            12000                0.0       496.0             360.0
# ...

# %%
#To get the summary
data.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
# Loan_ID              614 non-null object
# Gender               601 non-null object
# Married              611 non-null object
# Dependents           599 non-null object
# Education            614 non-null object
# Self_Employed        582 non-null object
# ApplicantIncome      614 non-null int64
# CoapplicantIncome    614 non-null float64
# LoanAmount           592 non-null float64
# Loan_Amount_Term     600 non-null float64
# Credit_History       564 non-null float64
# Property_Area        614 non-null object
# Loan_Status          614 non-null object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.4+ KB

# %%
#Access the Columns:
data['Loan_ID']
# Out:
# 0      LP001002
# 1      LP001003
# 2      LP001005
# 3      LP001006
# 4      LP001008
# 5      LP001011
# 6      LP001013
# 7      LP001014
# 8      LP001018
# 9      LP001020
# 10     LP001024
# 11     LP001027
# 12     LP001028
# 13     LP001029
# 14     LP001030
# 15     LP001032
# 16     LP001034
# 17     LP001036
# 18     LP001038
# 19     LP001041
# 20     LP001043
# 21     LP001046
# 22     LP001047
# 23     LP001050
# 24     LP001052
# 25     LP001066
# 26     LP001068
# 27     LP001073
# 28     LP001086
# 29     LP001087
#          ...
# 584    LP002911
# 585    LP002912
# 586    LP002916
# 587    LP002917
# 588    LP002925
# 589    LP002926
# 590    LP002928
# 591    LP002931
# 592    LP002933
# 593    LP002936
# 594    LP002938
# 595    LP002940
# 596    LP002941
# 597    LP002943
# 598    LP002945
# 599    LP002948
# 600    LP002949
# 601    LP002950
# 602    LP002953
# 603    LP002958
# 604    LP002959
# 605    LP002960
# 606    LP002961
# 607    LP002964
# ...

# %%
#Another way to access the Columns
data.Loan_ID
# Out:
# 0      LP001002
# 1      LP001003
# 2      LP001005
# 3      LP001006
# 4      LP001008
# 5      LP001011
# 6      LP001013
# 7      LP001014
# 8      LP001018
# 9      LP001020
# 10     LP001024
# 11     LP001027
# 12     LP001028
# 13     LP001029
# 14     LP001030
# 15     LP001032
# 16     LP001034
# 17     LP001036
# 18     LP001038
# 19     LP001041
# 20     LP001043
# 21     LP001046
# 22     LP001047
# 23     LP001050
# 24     LP001052
# 25     LP001066
# 26     LP001068
# 27     LP001073
# 28     LP001086
# 29     LP001087
#          ...
# 584    LP002911
# 585    LP002912
# 586    LP002916
# 587    LP002917
# 588    LP002925
# 589    LP002926
# 590    LP002928
# 591    LP002931
# 592    LP002933
# 593    LP002936
# 594    LP002938
# 595    LP002940
# 596    LP002941
# 597    LP002943
# 598    LP002945
# 599    LP002948
# 600    LP002949
# 601    LP002950
# 602    LP002953
# 603    LP002958
# 604    LP002959
# 605    LP002960
# 606    LP002961
# 607    LP002964
# ...

# %%
#Count of yes/no
data['Loan_Status'].value_counts()
# Out:
# Y    422
# N    192
# Name: Loan_Status, dtype: int64

# %%
# %matplotlib inline

# %%
#EDA
data['ApplicantIncome'].hist(bins=10)

# %%
#Box Plot
data.boxplot(column= 'ApplicantIncome')

# %%
data.boxplot(column='ApplicantIncome',by = 'Education')

# %%
#Checking Null Values
data.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
#Mean Imputation Techniques
data.Loan_Amount_Term.fillna(data.Loan_Amount_Term.mean(),inplace=True)

# %%
#Checking Null Values
data.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term      0
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
import numpy as np

# %%
#Replacing NA values with No
#data.Self_Employed.fillna('No',inplace=True)
#or
data.Self_Employed=data.Self_Employed.replace(np.nan,"Not Provided",regex=True)

# %%
#Checking Null Values
data.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed         0
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term      0
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
#Dropping all NA values
data = data.dropna()

# %%
#Checking Null Values
data.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
#Dropping The Columns
data = data.drop(['Gender'],axis=1)
data.head()
# Out:
#     Loan_ID Married Dependents     Education Self_Employed  ApplicantIncome  \
# 1  LP001003     Yes          1      Graduate            No             4583
# 2  LP001005     Yes          0      Graduate           Yes             3000
# 3  LP001006     Yes          0  Not Graduate            No             2583
# 4  LP001008      No          0      Graduate            No             6000
# 5  LP001011     Yes          2      Graduate           Yes             5417
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 1             1508.0       128.0             360.0             1.0
# 2                0.0        66.0             360.0             1.0
# 3             2358.0       120.0             360.0             1.0
# 4                0.0       141.0             360.0             1.0
# 5             4196.0       267.0             360.0             1.0
#
#   Property_Area Loan_Status
# 1         Rural           N
# 2         Urban           Y
# ...

# %%
#Accesing Specific Rows and Columns
#data[:] #Accessing Data from 5th Row of all columns
#data[4:] #Access data toll 5th Row
#data[from:to] Syntax

#data[-2:] #Accessing Data from last 2 records of all columns
#data[:-2]
#data[5:8] # Accessing Rows from 5th to 8th Row

#data.iloc[5] #Accessing All columns of 1st Row
#or
#data.loc[1] #Accessing All columns of 1st Row

#data[:] #Accessing all rows and Coulumns(Explicit Copy)

#iloc and loc operation to access row and column operations

#Need to specify Column Index
#Accessing Individual Columns via iloc operations
#data.iloc[:,0:10]
#data.iloc[:,2:4] 

#Need to specify Column names
#Accessing Individual Columns via loc operations
#data.loc[:,"Gender"]
#data.loc[:,["Gender","Married"]]
